# %% [markdown]
# <a href="https://colab.research.google.com/github/DangTrungNhut/Artificial_Intelligence_Course/blob/main/wk12_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube_search
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Mục mới

# %%
from youtube_search import YoutubeSearch
import webbrowser

# %%
mysong = input('Nhap vao ten bai hat')
# Out:
# Nhap vao ten bai hathihi

# %%
pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from openpyxl import Workbook

# %%
data = Workbook()
sheet = data.active

# %%
result = YoutubeSearch(mysong, max_results = 10).to_dict()
print(result)
for i in range(10):
  print(result[i]['url_suffix'])
  url = 'http://www.youtube.com'+result[i]['url_suffix']
  #i+=1
  print(url)
  sheet['A'+str(i+1)] = i+1
  sheet['B'+str(i+1)] = result[i]['title']
  sheet['C'+str(i+1)] = result[i]['url_suffix']
  sheet['D'+str(i+1)] = result[i]['views']
  sheet['E'+str(i+1)] = result[i]['duration']
  sheet['F'+str(i+1)] = result[i]['publish_time']
  sheet['G'+str(i+1)] = result[i]['channel']
  #webbrowser.open(url)
data.save('UTE.xlsx')
# Out:
# [{'id': 'hR7XqnEaPUo', 'thumbnails': ['https://i.ytimg.com/vi/hR7XqnEaPUo/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLC6mBWUQcGyDAkjUcIf-RRSOiVSUA', 'https://i.ytimg.com/vi/hR7XqnEaPUo/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLDQ5AK2lTJtUv0Be89QGCZvioVSpg'], 'title': 'HiHi Jets【ウソつきは誰？】インサイダーゲームって楽しいね!?', 'long_desc': None, 'channel': 'ジャニーズJr.チャンネル', 'duration': '19:08', 'views': '141,158 views', 'publish_time': '4 days ago', 'url_suffix': '/watch?v=hR7XqnEaPUo&pp=ygUEaGloaQ%3D%3D'}, {'id': 'rGqc0w_rW4Q', 'thumbnails': ['https://i.ytimg.com/vi/rGqc0w_rW4Q/hq720.jpg?sqp=-oaymwEjCOgCEMoBSFryq4qpAxUIARUAAAAAGAElAADIQj0AgKJDeAE=&rs=AOn4CLAYzvKxo3XRDVoU8vAuxaqcXDCXDA', 'https://i.ytimg.com/vi/rGqc0w_rW4Q/hq720.jpg?sqp=-oaymwEXCNAFEJQDSFryq4qpAwkIARUAAIhCGAE=&rs=AOn4CLBThhqBf7FiL-LG7HIsoaVhYxjiXg'], 'title': 'HOHO HIHI ON THE WEEKEND - KOMEDIAN CILIK (EPISODE 73)', 'long_desc': None, 'channel': 'Abdel Achrian', 'duration': '1:10:26
# ...

# %%
#Yeu cau wk13
#5 mau doi thoai (khong nen su dung tieng viet.wav, khoang 1 phut)
#5 doan bai hat(khong co intro, .wav)
#5 doan van ban(ngon ngu khac tieng viet)
#Dem theo tai nghe

# %%
########################################PRE_TRAINED MODEL########################################

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 26.4 MB/s eta 0:00:00
# ...

# %%
from mtcnn import MTCNN
import matplotlib.pyplot as plt

# %%
#filename1 = '/content/maridistar.jpg'
filename = '/content/manxanh.jpg'
img = plt.imread(filename)
plt.imshow(img)

# %%
detector = MTCNN()
faces = detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 7/7 [==============================] - 0s 15ms/step
# {'box': [793, 311, 44, 55], 'confidence': 0.9999992847442627, 'keypoints': {'left_eye': (806, 332), 'right_eye': (826, 331), 'nose': (818, 343), 'mouth_left': (809, 353), 'mouth_right': (825, 353)}}
# {'box': [549, 296, 37, 49], 'confidence': 0.9999982118606567, 'keypoints': {'left_eye': (559, 314), 'right_eye': (576, 313), 'nose': (569, 324), 'mouth_left': (562, 334), 'mouth_right': (576, 333)}}
# {'box': [676, 279, 40, 51], 'confidence': 0.9999953508377075, 'keypoints': {'left_eye': (690, 299), 'right_eye': (708, 298), 'nose': (700, 308), 'mouth_left': (692, 319), 'mouth_right': (706, 319)}}
# {'box': [828, 191, 39, 48], 'confidence': 0.9999951124191284, 'keypoints': {'left_eye': (840, 208), 'right_eye': (857, 208), 'nose': (848, 217), 'mouth_left': (842, 228), 'mouth_right': (855, 228)}}
# ...

# %%
filename = '/content/manxanh.jpg'
img = plt.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(img)
plt.imshow(img)
ax = plt.gca()

for face in faces:
  x,y,width,height = face['box']
  rect = plt.Rectangle((x,y), width, height, fill = False, color ='black')
  #print(face)
  ax.add_patch(rect)
  #plt.savefig('/content/drive/MyDrive/AI_COURSE/wk12_AI/manci.png')
  for key,value in face['keypoints'].items():
    dot = plt.Circle(value, radius = 2, color ='red')
    ax.add_patch(dot)
    #plt.savefig('/content/drive/MyDrive/AI_COURSE/wk12_AI/manci2.png')
plt.show()
# Out:
# ...
# 7/7 [==============================] - 0s 4ms/step

# %%
#Kết nối với drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from mtcnn import mtcnn
import matplotlib.pyplot as plt
def draw_faces(filename,result_list):
  data = plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height = result_list[i]['box']
    x2,y2 = x1 + width, y1 + height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
plt.show()
filename = '/content/manxanh.jpg'
img = plt.imread (filename)
detector = MTCNN()
faces = detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 7/7 [==============================] - 0s 3ms/step

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

#img_path = '/content/meo.jpg'
img_path = '/content/chuot.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# WARNING:tensorflow:5 out of the last 74 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f30c4759040> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 862ms/step
# Predicted: [('n02342885', 'hamster', 0.8465588), ('n03794056', 'mousetrap', 0.04324308), ('n02443484', 'black-footed_ferret', 0.012555588)]

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = VGG16(weights='imagenet')

img_path = '/content/meo.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f30c47594c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 799ms/step
# Predicted: [('n02123045', 'tabby', 0.2640062), ('n02124075', 'Egyptian_cat', 0.14515516), ('n02123159', 'tiger_cat', 0.14508167)]
